# %%
import numpy, scipy, matplotlib, cartopy, netCDF4, seaborn, mogreps

# %%
from pathlib import Path

# %%
forecast_1 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 1 , 12),data_folder = Path('.'))
forecast_2 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 2 , 12),data_folder = Path('.'))
forecast_3 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 3 , 12),data_folder = Path('.'))
forecast_4 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 4 , 12),data_folder = Path('.'))
forecast_5 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 5 , 12),data_folder = Path('.'))
forecast_6 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 6 , 12),data_folder = Path('.'))
forecast_7 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 7 , 12),data_folder = Path('.'))
forecast_8 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 8 , 12),data_folder = Path('.'))
forecast_9 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 9 , 12),data_folder = Path('.'))
forecast_10 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 10 , 12),data_folder = Path('.'))
forecast_11 = mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 11 , 12),data_folder = Path('.'))

control =  mogreps.download_data('mogreps-uk', mogreps.make_data_object_name('mogreps-uk', 2015, 12, 5, 3, 0 , 12),data_folder = Path('.'))
# Out:
# File prods_op_mogreps-uk_20151205_03_01_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_02_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_03_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_04_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_05_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_06_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_07_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_08_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_09_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_10_012.nc already exists.
# File prods_op_mogreps-uk_20151205_03_11_012.nc already exists.
# ...

# %%
DS_forecast_0 = netCDF4.Dataset(control)
DS_forecast_1 = netCDF4.Dataset(forecast_1)
DS_forecast_2 = netCDF4.Dataset(forecast_2)
DS_forecast_3 = netCDF4.Dataset(forecast_3)
DS_forecast_4 = netCDF4.Dataset(forecast_4)
DS_forecast_5 = netCDF4.Dataset(forecast_5)
DS_forecast_6 = netCDF4.Dataset(forecast_6)
DS_forecast_7 = netCDF4.Dataset(forecast_7)
DS_forecast_8 = netCDF4.Dataset(forecast_8)
DS_forecast_9 = netCDF4.Dataset(forecast_9)
DS_forecast_10 = netCDF4.Dataset(forecast_10)
DS_forecast_11 = netCDF4.Dataset(forecast_11)

forecasts = [DS_forecast_0, DS_forecast_1, DS_forecast_2, DS_forecast_3, DS_forecast_4, DS_forecast_5, DS_forecast_6, DS_forecast_7, DS_forecast_8, DS_forecast_9, DS_forecast_10, DS_forecast_11]

# %%
import cartopy.crs as ccrs
from matplotlib import pyplot as plt

# %%
test_variable = "stratiform_rainfall_rate"
v_min = 0
v_max = 0.003


rotation = forecasts[0]['rotated_latitude_longitude']
transform = ccrs.RotatedPole(pole_longitude=rotation.grid_north_pole_longitude, pole_latitude = rotation.grid_north_pole_latitude)
projection = transform
fig = plt.figure(figsize=(20,10))
for i in range(0,12):
    ax = fig.add_subplot(3,4,i+1, projection=projection)
    pcm = ax.pcolormesh(
        forecasts[i]['grid_longitude'],
        forecasts[i]['grid_latitude'],
        forecasts[i][test_variable][35],
        transform=transform, vmin = v_min, vmax = v_max, cmap = 'Blues')
    ax.coastlines(resolution='10m')
    ax.set_title("Ensemble Member "+str(i+1))
    plt.colorbar(pcm,ax=ax)

# %%
test_variable = "air_pressure_at_sea_level"
v_min = 97000
v_max = 103000

rotation = forecasts[0]['rotated_latitude_longitude']
transform = ccrs.RotatedPole(pole_longitude=rotation.grid_north_pole_longitude, pole_latitude = rotation.grid_north_pole_latitude)
projection = transform
fig = plt.figure(figsize=(20,10))
for i in range(0,12):
    ax = fig.add_subplot(3, 4,i+1, projection=projection)
    pcm = ax.pcolormesh(
        forecasts[i]['grid_longitude'],
        forecasts[i]['grid_latitude'],
        forecasts[i][test_variable][2],
        transform=transform, vmin = v_min, vmax = v_max, cmap = 'seismic')
    ax.coastlines(resolution='10m')
    ax.set_title("Ensemble Member "+str(i+1))
    plt.colorbar(pcm,ax=ax)

# %%
rotation = forecasts[5]['rotated_latitude_longitude']
transform = ccrs.RotatedPole(pole_longitude=rotation.grid_north_pole_longitude, pole_latitude = rotation.grid_north_pole_latitude)
projection = transform
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(231, projection=projection)
pcm = ax.pcolormesh(
    forecasts[5]['grid_longitude'],
    forecasts[5]['grid_latitude'],
    forecasts[5][test_variable][2],
    transform=transform, vmin = 97000, vmax = 103000, cmap = 'seismic')
ax.coastlines(resolution='10m')
ax.set_title("Ensemble member 5")
plt.colorbar(pcm,ax=ax)
